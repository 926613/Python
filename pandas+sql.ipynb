# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    "mssql+pyodbc://@DESKTOP-EE4F4UR\SQLEXPRESS/SalesDB"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

#df = pd.read_sql("SELECT  * FROM customers", engine)

# %%
df
# Out:
#    id first_name  country  score
# 0   1      Maria  Germany    900
# 1   2       John      USA    900
# 2   3      Georg       UK    750
# 3   4     Martin  Germany    500
# 4   5      Peter      USA      0

# %%
total_sum = df.groupby('country')['score'].sum()

# %%
total_sum
# Out:
# country
# Germany    1400
# UK          750
# USA         900
# Name: score, dtype: int64

# %%
#engine.dispose()  # close the database connection

# %%
df2 = pd.read_sql('Select * from Sales.Orders', engine)

# %%
df2.head()
# Out:
#    OrderID  ProductID  CustomerID  SalesPersonID   OrderDate    ShipDate  \
# 0        1        101           2              3  2025-01-01  2025-01-05
# 1        2        102           3              3  2025-01-05  2025-01-10
# 2        3        101           1              5  2025-01-10  2025-01-25
# 3        4        105           1              3  2025-01-20  2025-01-25
# 4        5        104           2              5  2025-02-01  2025-02-05
#
#   OrderStatus         ShipAddress    BillAddress  Quantity  Sales  \
# 0   Delivered  9833 Mt. Dias Blv.  1226 Shoe St.         1     10
# 1     Shipped      250 Race Court           None         1     15
# 2   Delivered        8157 W. Book   8157 W. Book         2     20
# 3     Shipped   5724 Victory Lane                        2     60
# 4   Delivered                None           None         1     25
#
#          CreationTime
# 0 2025-01-01 12:34:56
# 1 2025-01-05 23:22:04
# 2 2025-01-10 18:24:08
# 3 2025-01-20 05:50:33
# ...

# %%
sales_for_each_cust = df2.groupby('CustomerID')['Sales'].sum() 
print(sales_for_each_cust)
# Out:
# CustomerID
# 1    110
# 2     55
# 3    125
# 4     90
# Name: Sales, dtype: int64

# %%
sorted_data = df2.sort_values(by = 'Sales', ascending = False)

# %%
sorted_data[['OrderID', 'OrderDate', 'Sales']]
# Out:
#    OrderID   OrderDate  Sales
# 7        8  2025-02-18     90
# 3        4  2025-01-20     60
# 9       10  2025-03-15     60
# 5        6  2025-02-05     50
# 6        7  2025-02-15     30
# 4        5  2025-02-01     25
# 2        3  2025-01-10     20
# 8        9  2025-03-10     20
# 1        2  2025-01-05     15
# 0        1  2025-01-01     10

# %%
df2
# Out:
#    OrderID  ProductID  CustomerID  SalesPersonID   OrderDate    ShipDate  \
# 0        1        101           2              3  2025-01-01  2025-01-05
# 1        2        102           3              3  2025-01-05  2025-01-10
# 2        3        101           1              5  2025-01-10  2025-01-25
# 3        4        105           1              3  2025-01-20  2025-01-25
# 4        5        104           2              5  2025-02-01  2025-02-05
# 5        6        104           3              5  2025-02-05  2025-02-10
# 6        7        102           1              1  2025-02-15  2025-02-27
# 7        8        101           4              3  2025-02-18  2025-02-27
# 8        9        101           2              3  2025-03-10  2025-03-15
# 9       10        102           3              5  2025-03-15  2025-03-20
#
#   OrderStatus         ShipAddress    BillAddress  Quantity  Sales  \
# 0   Delivered  9833 Mt. Dias Blv.  1226 Shoe St.         1     10
# ...

# %%
sales = df2[['Sales']]

# %%
import numpy as np

# %%
arr = np.array(sales).reshape(10)

# %%
print(arr.ndim)
print(arr.shape)
print(arr.dtype)
# Out:
# 1
# (10,)
# int64

# %%
print(np.sum(sales, axis = 1))
# Out:
# 0    10
# 1    15
# 2    20
# 3    60
# 4    25
# 5    50
# 6    30
# 7    90
# 8    20
# 9    60
# dtype: int64

# %%
df2
# Out:
#    OrderID  ProductID  CustomerID  SalesPersonID   OrderDate    ShipDate  \
# 0        1        101           2              3  2025-01-01  2025-01-05
# 1        2        102           3              3  2025-01-05  2025-01-10
# 2        3        101           1              5  2025-01-10  2025-01-25
# 3        4        105           1              3  2025-01-20  2025-01-25
# 4        5        104           2              5  2025-02-01  2025-02-05
# 5        6        104           3              5  2025-02-05  2025-02-10
# 6        7        102           1              1  2025-02-15  2025-02-27
# 7        8        101           4              3  2025-02-18  2025-02-27
# 8        9        101           2              3  2025-03-10  2025-03-15
# 9       10        102           3              5  2025-03-15  2025-03-20
#
#   OrderStatus         ShipAddress    BillAddress  Quantity  Sales  \
# 0   Delivered  9833 Mt. Dias Blv.  1226 Shoe St.         1     10
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10, 5))
sns.countplot(data = df2, x = 'CustomerID', hue = 'CustomerID', legend = False)
plt.title('Total Sales for Customer')
plt.xlabel('Customer ID')
plt.ylabel('Total orders')
plt.show()
