# %% [markdown]
# ### Pandas is a powerful python library used for data manipulation and analysis
#  ####  It offers powerful and flexible data structure such as series(1D) and Dataframe(2D)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Creating Series Manually

# %%
s = pd.Series([10, 20, 30, 40, 50], index = ('a', 'b', 'c', 'd', 'e'))
print(s)
print(s['a'])
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# 10

# %%
prices = [700000, 8900000, 1400000]
car_name = ['Boleno', 'BMW', 'Scarpio']
car_series = pd.Series(prices, car_name)
print(car_series)
# Out:
# Boleno      700000
# BMW        8900000
# Scarpio    1400000
# dtype: int64

# %%
type(car_series)
# Out:
# pandas.core.series.Series

# %%
print(pd.Series(prices))
# Out:
# 0     700000
# 1    8900000
# 2    1400000
# dtype: int64

# %%
car_series = pd.Series(data = prices, index = car_name, name = 'prices')
print(car_series)
# Out:
# Boleno      700000
# BMW        8900000
# Scarpio    1400000
# Name: prices, dtype: int64

# %% [markdown]
# ##### Creating series from dictionary

# %%
data_car = {
    'Boleno': 900000,
    'Audi': 600000,
    'Bolero': 1200000,
    'Santro': 310000,
    'Nano': 190000
}

car_series = pd.Series(data_car, name= 'prices')

# %%
print(car_series)
# Out:
# Boleno     900000
# Audi       600000
# Bolero    1200000
# Santro     310000
# Nano       190000
# Name: prices, dtype: int64

# %%
type(car_series['Audi'])
# Out:
# numpy.int64

# %%
type(car_series['Bolero'])
# Out:
# numpy.int64

# %%
len(car_series)
# Out:
# 5

# %%
car_series.ndim
# Out:
# 1

# %%
car_series > 1000000
# Out:
# Boleno    False
# Audi      False
# Bolero     True
# Santro    False
# Nano      False
# Name: prices, dtype: bool

# %%
print(car_series[car_series > 500000])
# Out:
# Boleno     900000
# Audi       600000
# Bolero    1200000
# Name: prices, dtype: int64

# %%
car_series[car_series > 500000].index[0]
# Out:
# 'Boleno'

# %%
car_series[car_series > 500000].index[2]
# Out:
# 'Bolero'

# %%
print(car_series[car_series > 500000].values[1])
# Out:
# 600000

# %%
car_series[(car_series > 500000) & (car_series < 1000000)]
# Out:
# Boleno    900000
# Audi      600000
# Name: prices, dtype: int64

# %%
bill = [100, 250.23, 340, 124, 516]
cust_name = ['Rohan', 'Sohan', 'Mohan', 'Mohit', 'Sohit']

# %%
cust_info = pd.Series(bill, index = cust_name, name = 'Bill')
print(cust_info)
# Out:
# Rohan    100.00
# Sohan    250.23
# Mohan    340.00
# Mohit    124.00
# Sohit    516.00
# Name: Bill, dtype: float64

# %%
print(list(cust_info[cust_info > 300].index))
# Out:
# ['Mohan', 'Sohit']

# %% [markdown]
# ### Accessing data from Series using .loc[] method

# %%
# The .loc in pandas stands for location and is a property used for label-based indexing to select or
# filter data from a DataFrame or Series. 
# It allows you to access groups of rows and columns using their assigned labels (names) rather 
# than their integer positions.

# %%
# While you can slice rows using df[start:end], this method is position-based. 
# If your index contains labels, you lose the safety and clarity of label-based slicing that loc provides.

# %%
 print(car_series.loc['Santro'])
# Out:
# 310000

# %%
car_series.loc[['Santro']]
# Out:
# Santro    310000
# Name: prices, dtype: int64

# %%
print(car_series)
# Out:
# Boleno      700000
# BMW        8900000
# Scarpio    1400000
# dtype: int64

# %%
print(car_series.loc[['Boleno', 'Nano']])
# Out:
# Boleno    900000
# Nano      190000
# Name: prices, dtype: int64

# %%
print(car_series.loc['Audi':'Santro'])
# Out:
# Audi       600000
# Bolero    1200000
# Santro     310000
# Name: prices, dtype: int64

# %%
print(car_series.loc[: 'Santro'])
# Out:
# Boleno     900000
# Audi       600000
# Bolero    1200000
# Santro     310000
# Name: prices, dtype: int64

# %% [markdown]
# ### iloc method

# %%
print(car_series.iloc[1])
# Out:
# 600000

# %%
print(car_series.iloc[[1]])
# Out:
# Audi    600000
# Name: prices, dtype: int64

# %%
print(car_series.iloc[[1, 2, 3]])
# Out:
# Audi       600000
# Bolero    1200000
# Santro     310000
# Name: prices, dtype: int64

# %%
print(car_series.iloc[1: 4])
# Out:
# Audi       600000
# Bolero    1200000
# Santro     310000
# Name: prices, dtype: int64

# %%
## iloc dosen't include the stop element like loc method

# %%
print(car_series.iloc[: : -1])
# Out:
# Nano       190000
# Santro     310000
# Bolero    1200000
# Audi       600000
# Boleno     900000
# Name: prices, dtype: int64

# %%
 print(car_series.iloc[0:5:2])
# Out:
# Boleno     900000
# Bolero    1200000
# Nano       190000
# Name: prices, dtype: int64

# %% [markdown]
# # DataFrame

# %%
df = pd.DataFrame({
    'Product': ['Toothpaste', 'Soap', 'tiolet-paper'],
    'Price': [90, np.nan , 190],
    'Qunatity': [3, 7, 2]
})

# %%
df # it is dataframe object
# Out:
#         Product  Price  Qunatity
# 0    Toothpaste   90.0         3
# 1          Soap    NaN         7
# 2  tiolet-paper  190.0         2

# %%
# create csv file
# to_csv() means save the DataFrame as a CSV file
df.to_csv('Grocery_products.csv', index = False)
print('File successfully created')

# Those 0, 1, 2 are row numbers (index), not real data.

# index=False means:

# 👉 Do NOT save the index column
# Out:
# File successfully created

# %% [markdown]
# ### Read CSV file

# %%
data_csv = pd.read_csv('Grocery_products.csv') # load csv file as a table(dataframe)
print(data_csv)
# Out:
#         Product  Price  Qunatity
# 0    Toothpaste     90         3
# 1          Soap    100         7
# 2  tiolet-paper    190         2

# %%
data_csv
# Out:
#         Product  Price  Qunatity
# 0    Toothpaste     90         3
# 1          Soap    100         7
# 2  tiolet-paper    190         2

# %%
print(data_csv['Price'])
# Out:
# 0     90
# 1    100
# 2    190
# Name: Price, dtype: int64

# %%
price = np.array(data_csv['Price'])

# %%
print(np.sum(price))
# Out:
# 380

# %%
print(np.max(price))
print(np.min(price))
# Out:
# 190
# 90

# %%
# Returns a DataFrame with two columns
subset_df = data_csv[['Product', 'Price']]

# Returns a Series (1D)
single_col = data_csv['Product']

# Returns a DataFrame (2D)
single_col_df = data_csv[['Product']]

single_col_df
# Out:
#         Product
# 0    Toothpaste
# 1          Soap
# 2  tiolet-paper

# %%
file_path = r"C:\Users\admin\first jupyter notebook\pharma_sales_data.csv"
df1 = pd.read_csv(file_path)

# %%
df1
# Out:
#    Product_ID Product_Name      Category  Sales_Units  Revenue Region
# 0         101   PainRelief     Analgesic        500.0  25000.0  North
# 1         102   CoughSyrup  Cough & Cold        300.0  12000.0  South
# 2         103  AntibioticX    Antibiotic          NaN  40000.0   East
# 3         104     VitaminD    Supplement        700.0      NaN   West
# 4         105  DiabetesMed      Diabetes        450.0  31500.0  North
# 5         106      Antacid     Digestive          NaN  18000.0  South
# 6         107  AllergyPill       Allergy        600.0      NaN   East
# 7         108      FluShot       Vaccine        800.0  56000.0   West

# %%
df1.head() # it print top 5 rows
# Out:
#    Product_ID Product_Name      Category  Sales_Units  Revenue Region
# 0         101   PainRelief     Analgesic        500.0  25000.0  North
# 1         102   CoughSyrup  Cough & Cold        300.0  12000.0  South
# 2         103  AntibioticX    Antibiotic          NaN  40000.0   East
# 3         104     VitaminD    Supplement        700.0      NaN   West
# 4         105  DiabetesMed      Diabetes        450.0  31500.0  North

# %%
df1.head(3)
# Out:
#    Product_ID Product_Name      Category  Sales_Units  Revenue Region
# 0         101   PainRelief     Analgesic        500.0  25000.0  North
# 1         102   CoughSyrup  Cough & Cold        300.0  12000.0  South
# 2         103  AntibioticX    Antibiotic          NaN  40000.0   East

# %%
df1[['Product_ID', 'Product_Name', 'Sales_Units']]
# Out:
#    Product_ID Product_Name  Sales_Units
# 0         101   PainRelief        500.0
# 1         102   CoughSyrup        300.0
# 2         103  AntibioticX          NaN
# 3         104     VitaminD        700.0
# 4         105  DiabetesMed        450.0
# 5         106      Antacid          NaN
# 6         107  AllergyPill        600.0
# 7         108      FluShot        800.0

# %%
df1.tail(4) # display last 5 rows by default(if you can't pass any parameters)
# Out:
#    Product_ID Product_Name   Category  Sales_Units  Revenue Region
# 4         105  DiabetesMed   Diabetes        450.0  31500.0  North
# 5         106      Antacid  Digestive          NaN  18000.0  South
# 6         107  AllergyPill    Allergy        600.0      NaN   East
# 7         108      FluShot    Vaccine        800.0  56000.0   West

# %%
df1.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    8 non-null      int64
#  1   Product_Name  8 non-null      object
#  2   Category      8 non-null      object
#  3   Sales_Units   6 non-null      float64
#  4   Revenue       6 non-null      float64
#  5   Region        8 non-null      object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 516.0+ bytes

# %%
df1.describe() # it display summary of statistics
# Out:
#        Product_ID  Sales_Units       Revenue
# count     8.00000     6.000000      6.000000
# mean    104.50000   558.333333  30416.666667
# std       2.44949   180.046290  15938.684596
# min     101.00000   300.000000  12000.000000
# 25%     102.75000   462.500000  19750.000000
# 50%     104.50000   550.000000  28250.000000
# 75%     106.25000   675.000000  37875.000000
# max     108.00000   800.000000  56000.000000

# %% [markdown]
# ## Handling missing values
# ### Methods of handling missing valuse:
# #### -Imputation: filling missing values with mean/median/mode.
# #### -Deletion: remove rows/columns with missing values.

# %%
dc = pd.read_csv('data_clean.csv')

# %%
dc
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
dc.head(5)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
dc.tail()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
dc.isnull()
# Out:
#      Unnamed: 0  Ozone  Solar.R   Wind  Temp C  Month    Day   Year   Temp  \
# 0         False  False    False  False   False  False  False  False  False
# 1         False  False    False  False   False  False  False  False  False
# 2         False  False    False  False   False  False  False  False  False
# 3         False  False    False  False   False  False  False  False  False
# 4         False   True     True  False   False  False  False  False  False
# ..          ...    ...      ...    ...     ...    ...    ...    ...    ...
# 153       False  False    False  False   False  False  False  False  False
# 154       False  False    False  False   False  False  False  False  False
# 155       False   True    False  False   False  False  False  False  False
# 156       False  False    False  False   False  False  False  False  False
# 157       False  False    False  False   False  False  False  False  False
#
#      Weather
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
#
# [158 rows x 10 columns]

# %%
print('Missing values:\n', dc.isnull().sum()) # cal. total missing values in each column
# Out:
# Missing values:
#  Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
# dc.isnull(): This method generates a new DataFrame of the same size as dc, 
# but with boolean values. Each cell is True if the corresponding cell in dc is null (e.g., NaN, None, or NaT) and False otherwise.
# .sum(): When the sum() method is applied to the boolean DataFrame, it treats True as 1 and False as 0. 
#  By default, the sum is calculated down the columns (axis 0). 
# The result is a pandas Series where the index contains the column names of dc, 
# and the values represent the total count of null entries in that specific column.

# %%
# before imputation 
dc[['Ozone']]
# Out:
#      Ozone
# 0     41.0
# 1     36.0
# 2     12.0
# 3     18.0
# 4     30.5
# ..     ...
# 153   41.0
# 154   30.0
# 155   30.5
# 156   14.0
# 157   18.0
#
# [158 rows x 1 columns]

# %%
# impute ozone with median
ozone_median = dc['Ozone'].median()
print(ozone_median)
# Out:
# 30.5

# %%
w = dc['Ozone'].fillna(ozone_median)#, inplace = True)
#This parameter tells Pandas to modify the existing dc DataFrame directly rather than returning a new modified copy.

# %%
dc[['Ozone']]
# Out:
#      Ozone
# 0     41.0
# 1     36.0
# 2     12.0
# 3     18.0
# 4     30.5
# ..     ...
# 153   41.0
# 154   30.0
# 155   30.5
# 156   14.0
# 157   18.0
#
# [158 rows x 1 columns]

# %%
solar_mean = dc['Solar.R'].mean()
print(solar_mean)
# Out:
# 185.40397350993376

# %%
dc['Solar.R'].fillna(solar_mean, inplace = True)

# %%
dc[['Solar.R']]
# Out:
#         Solar.R
# 0    190.000000
# 1    118.000000
# 2    149.000000
# 3    313.000000
# 4    185.403974
# ..          ...
# 153  190.000000
# 154  193.000000
# 155  145.000000
# 156  191.000000
# 157  131.000000
#
# [158 rows x 1 columns]

# %%
print(dc['Weather'].isna().sum())
# Out:
# 3

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       158 non-null    float64
#  2   Solar.R     158 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
dc['Weather']
# Out:
# 0       S
# 1       C
# 2      PS
# 3       S
# 4       S
#        ..
# 153     C
# 154    PS
# 155     S
# 156     S
# 157     C
# Name: Weather, Length: 158, dtype: object

# %%
dc['Weather'].mode()
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
we_mode = dc['Weather'].mode()[0]
we_mode
# Out:
# 'S'

# %%
dc['Weather'].fillna(we_mode, inplace = True)

# %%
dc['Weather'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Aggregations

# %%
# we = dc.groupby('Weather')
# print(we['Temp'].mean())

we = dc.groupby('Weather')['Temp'].mean()
print(np.ceil(np.array(we)))
# Out:
# [78. 77. 79.]

# %%
max_wind_speed = dc.groupby('Month')['Wind'].max()
print(max_wind_speed)
# Out:
# Month
# 5      20.1
# 6      20.7
# 7      14.9
# 8      15.5
# 9      16.6
# May    12.0
# Name: Wind, dtype: float64

# %%
df3 = pd.read_csv('salaries.csv')
df3.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
total_salary = df3.groupby('rank')['salary'].sum()
total_salary
# Out:
# rank
# AssocProf    1193221
# AsstProf     1545893
# Prof         5686741
# Name: salary, dtype: int64

# %%
max_value = df3.groupby('sex')['service'].max()
max_value
# Out:
# sex
# Female    36
# Male      51
# Name: service, dtype: int64

# %% [markdown]
# ## Sorting

# %% [markdown]
# ### sort_values(): sort data acc. to column name
# ### parameters: by = columns_name , ascending = (True/False)

# %%
# sorted_data = dc.sort_values(by = 'Temp', ascending = False)
sorted_data = dc.sort_values(by = ['Temp', 'Month'], ascending = [False, False])

# %%
sorted_data[['Temp', 'Month']].head()
# Out:
#      Temp Month
# 119    97     8
# 121    96     8
# 122    94     8
# 120    94     8
# 41     93     6

# %% [markdown]
# ## Case Study
# ### Handling missing values and aggregate records

# %% [markdown]
# #### Step1. Read CSV file

# %%
df = pd.read_csv('encounters.csv')
df.head()
# Out:
#                                      Id                 START  \
# 0  32c84703-2481-49cd-d571-3899d5820253  2011-01-02T09:26:36Z
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  2011-01-03T05:44:39Z
# 2  4ad28a3a-2479-782b-f29c-d5b3f41a001e  2011-01-03T14:32:11Z
# 3  c3f4da61-e4b4-21d5-587a-fbc89943bc19  2011-01-03T16:24:45Z
# 4  a9183b4f-2572-72ea-54c2-b3cd038b4be7  2011-01-03T17:36:53Z
#
#                    STOP                               PATIENT  \
# 0  2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  2011-01-03T06:01:42Z  d9ec2e44-32e9-9148-179a-1653348cc4e2
# 2  2011-01-03T14:47:11Z  73babadf-5b2b-fee7-189e-6f41ff213e01
# 3  2011-01-03T16:39:45Z  3b46a0b7-0f34-9b9a-c319-ace4a1f58c0b
# 4  2011-01-03T17:51:53Z  fa006887-d93c-d302-8b89-f3c25f88c0e1
#
#                            ORGANIZATION                                 PAYER  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 2  d78e84ec-30aa-3bba-a33a-f29a3a454662  7caa7254-5050-3b5e-9eae-bd5ea30e809c
# 3  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 4  d78e84ec-30aa-3bba-a33a-f29a3a454662  42c4fca7-f8a9-3cd1-982a-dd9751bf3e2a
#
#   ENCOUNTERCLASS       CODE                                 DESCRIPTION  \
# 0     ambulatory  185347001           Encounter for problem (procedure)
# 1     outpatient  308335008                 Patient encounter procedure
# 2     outpatient  185349003          Encounter for check up (procedure)
# 3       wellness  162673000  General examination of patient (procedure)
# 4     ambulatory  390906007                         Follow-up encounter
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02            0.00         NaN
# 1               142.58           2619.36            0.00         NaN
# 2                85.55            461.59          305.27         NaN
# 3               136.80           1784.24            0.00         NaN
# 4                85.55            234.72            0.00  55822004.0
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4    Hyperlipidemia

# %%
df.isna().sum()
# Out:
# Id                         0
# START                      0
# STOP                       0
# PATIENT                    0
# ORGANIZATION               0
# PAYER                      0
# ENCOUNTERCLASS             0
# CODE                       0
# DESCRIPTION                0
# BASE_ENCOUNTER_COST        0
# TOTAL_CLAIM_COST           0
# PAYER_COVERAGE             0
# REASONCODE             19541
# REASONDESCRIPTION      19541
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   27891 non-null  object
#  1   START                27891 non-null  object
#  2   STOP                 27891 non-null  object
#  3   PATIENT              27891 non-null  object
#  4   ORGANIZATION         27891 non-null  object
#  5   PAYER                27891 non-null  object
#  6   ENCOUNTERCLASS       27891 non-null  object
#  7   CODE                 27891 non-null  int64
#  8   DESCRIPTION          27891 non-null  object
#  9   BASE_ENCOUNTER_COST  27891 non-null  float64
#  10  TOTAL_CLAIM_COST     27891 non-null  float64
#  11  PAYER_COVERAGE       27891 non-null  float64
#  12  REASONCODE           8350 non-null   float64
#  13  REASONDESCRIPTION    8350 non-null   object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 3.0+ MB

# %% [markdown]
# #### Step2. select and filter column

# %%
df[['Id', 'PATIENT', 'PAYER', 'ENCOUNTERCLASS', 'DESCRIPTION', 'TOTAL_CLAIM_COST']].head()
# Out:
#                                       Id  \
# 4   a9183b4f-2572-72ea-54c2-b3cd038b4be7
# 7   2cfd4ddd-ad13-fe1e-528b-15051cea2ec3
# 9   17966936-0878-f4db-128b-a43ae10d0878
# 14  4b6a38e6-7df9-2d75-d850-6bd662f3d05b
# 16  f39e72a6-a58e-0aea-cc1f-8aee6f126cc0
#
#                                  PATIENT  \
# 4   fa006887-d93c-d302-8b89-f3c25f88c0e1
# 7   d856d6e6-4c98-e7a2-129b-44076c63d008
# 9   bc9d59c3-0a30-6e3b-f47d-022e4f03c8de
# 14  bc9d59c3-0a30-6e3b-f47d-022e4f03c8de
# 16  88986fec-6364-262e-37d4-e20ceb511166
#
#                                    PAYER ENCOUNTERCLASS  \
# 4   42c4fca7-f8a9-3cd1-982a-dd9751bf3e2a     ambulatory
# 7   7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a     ambulatory
# 9   7caa7254-5050-3b5e-9eae-bd5ea30e809c     outpatient
# 14  7caa7254-5050-3b5e-9eae-bd5ea30e809c     outpatient
# 16  7caa7254-5050-3b5e-9eae-bd5ea30e809c     ambulatory
#
#               DESCRIPTION  TOTAL_CLAIM_COST
# 4     Follow-up encounter            234.72
# 7   Encounter for problem          11855.19
# 9   Encounter for problem           9881.17
# 14  Encounter for problem           5136.00
# 16    Follow-up encounter            234.72

# %%
base_medain = df['BASE_ENCOUNTER_COST'].median()
base_medain
# Out:
# 136.8

# %%
# drop nan
df['REASONDESCRIPTION'].isnull().sum()
# Out:
# np.int64(19541)

# %%
df.dropna(subset= ['REASONDESCRIPTION'], inplace = True)

# dropna(): This method is used to remove rows or columns containing missing values.
# subset=['REASONDESCRIPTION']: This restricts the check for missing values only to the 'REASONDESCRIPTION' column. 
#If a row has a missing value in other columns, it will not be dropped; it only drops the row if 'REASONDESCRIPTION' is empty.
# inplace=True: This modifies the original DataFrame df directly, rather than returning a new DataFrame object. 
#As a result, this method returns None.

# %%
#df.isna().sum()
df['REASONDESCRIPTION']
# Out:
# 4                                           Hyperlipidemia
# 7                                 Malignant tumor of colon
# 9                    Non-small cell lung cancer (disorder)
# 14       Non-small cell carcinoma of lung  TNM stage 1 ...
# 16                                          Hyperlipidemia
#                                ...
# 27871          Chronic congestive heart failure (disorder)
# 27879                           Viral sinusitis (disorder)
# 27880          Chronic congestive heart failure (disorder)
# 27888                                     Normal pregnancy
# 27890          Chronic congestive heart failure (disorder)
# Name: REASONDESCRIPTION, Length: 8350, dtype: object

# %%
# aggregation

# %%
avg_cost_class = df.groupby('ENCOUNTERCLASS')['BASE_ENCOUNTER_COST'].mean()
avg_cost_class
# Out:
# ENCOUNTERCLASS
# ambulatory    110.034084
# emergency     139.201323
# inpatient     135.808129
# outpatient     85.550000
# wellness      136.800000
# Name: BASE_ENCOUNTER_COST, dtype: float64

# %%
az = df.groupby('PAYER')['TOTAL_CLAIM_COST'].sum()

# %%
az
# Out:
# PAYER
# 047f6ec3-6215-35eb-9608-f9dda363a44c    1195513.62
# 42c4fca7-f8a9-3cd1-982a-dd9751bf3e2a    1700220.24
# 4d71f845-a6a9-3c39-b242-14d25ef86a8d    1091943.15
# 5059a55e-5d6e-34d1-b6cb-d83d16e57bcf    1051841.75
# 6e2f1a2d-27bd-3701-8d08-dae202c58632    1623290.20
# 7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a    7165889.64
# 7caa7254-5050-3b5e-9eae-bd5ea30e809c    2828182.83
# b1c428d6-4f07-31e0-90f0-68ffa6ff8c76    9983932.33
# b3221cfc-24fb-339e-823d-bc4136cbc4ed     534523.99
# d47b3510-2895-3b70-9897-342d681c769d    1354417.07
# Name: TOTAL_CLAIM_COST, dtype: float64

# %%
# SORTING

# %%
sorted_data = df.sort_values(by= 'BASE_ENCOUNTER_COST', ascending = False)
#sorted_data.head()
sorted_data[['Id', 'BASE_ENCOUNTER_COST']].head()
# Out:
#                                          Id  BASE_ENCOUNTER_COST
# 9282   90e4e925-7e6f-2be4-1936-ebbdd0b4f72c               146.18
# 24285  bb3c86bd-82f2-5649-1143-1ee3b6212de6               146.18
# 24198  c5ee7ce0-7cb1-35eb-8997-c01f6974dc46               146.18
# 24215  142a6a81-5fe2-c090-1161-ea59a6ccefc8               146.18
# 5164   4e1da21d-49ec-5426-e752-b920e74b255a               146.18

# %%
avg_claim_cost = df.groupby('ENCOUNTERCLASS')['TOTAL_CLAIM_COST'].mean()
avg_claim_cost
# Out:
# ENCOUNTERCLASS
# ambulatory    3207.561614
# emergency     5193.448161
# inpatient     5569.373840
# outpatient    6280.394444
# wellness         0.000000
# Name: TOTAL_CLAIM_COST, dtype: float64

# %%
new_df = df[df['ENCOUNTERCLASS'] == 'emergency'].copy()
mean_value = new_df['TOTAL_CLAIM_COST'].mean()

# %%
print(mean_value)
# Out:
# 5193.448161290323
